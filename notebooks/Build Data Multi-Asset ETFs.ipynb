# %%
import pandas as pd
import numpy as np

import yfinance as yf

# %%
info = pd.DataFrame(columns=['ETF Description'])
info.loc['SPY'] = 'Domestic Equity SPDR S&P500'
info.loc['EFA'] = 'Foreign Equity iShares EAFE'
info.loc['EEM'] = 'iShares Emerging Markets'
info.loc['PSP'] = 'Private Equity Invesco Global Private Equity'
info.loc['QAI'] = 'Absolute Return IQ Multi-Strat'
info.loc['HYG'] = 'High Yield iShares High Yield Corporate Bond'
info.loc['DBC'] = 'Invesco DB Commodity Index Tracking Fund'
info.loc['IYR'] = 'Real Estate iShares US Real Estate'
info.loc['IEF'] = 'Domestic Bonds iShares 7-10 Year Treasury'
info.loc['BWX'] = 'Foreign Bonds SPDR Bloomberg Barclay International Treasury'
info.loc['TIP'] = 'Inflation-Indexed iShares TIPS Bond'
info.loc['SHV'] = 'iShares Short Treasury Bond'
info
# Out:
#                                        ETF Description
# SPY                        Domestic Equity SPDR S&P500
# EFA                        Foreign Equity iShares EAFE
# EEM                           iShares Emerging Markets
# PSP       Private Equity Invesco Global Private Equity
# QAI                     Absolute Return IQ Multi-Strat
# HYG       High Yield iShares High Yield Corporate Bond
# DBC           Invesco DB Commodity Index Tracking Fund
# IYR                 Real Estate iShares US Real Estate
# IEF          Domestic Bonds iShares 7-10 Year Treasury
# BWX  Foreign Bonds SPDR Bloomberg Barclay Internati...
# TIP                Inflation-Indexed iShares TIPS Bond
# SHV                        iShares Short Treasury Bond

# %%
tickers = list(info.index.values)
df = yf.download(tickers, start="2007-01-01", end="2021-06-30")['Adj Close']
# Out:
# [*********************100%***********************]  12 of 12 completed

# %%
prices = df.resample('M').last()
rets = prices.pct_change()
# use subsample starting in 2009-04-30 to avoid NaN
start_date = '2009-04-30'
rets = rets.loc[start_date:]
# change to excess returns, in excess of short-term treasury
retsx = rets.subtract(rets['SHV'], axis=0)
retsx = retsx.drop(columns=['SHV'])

# %%
rets
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008992 -0.001000  0.155582  0.115190  0.138460 -0.027452
# 2009-05-31  0.053672  0.162663  0.159400  0.131918  0.028554 -0.020773
# 2009-06-30  0.005149 -0.026259 -0.022495 -0.014049  0.033518 -0.005571
# 2009-07-31  0.031284  0.018568  0.110146  0.100415  0.069190  0.008316
# 2009-08-31  0.007628 -0.040365 -0.013136  0.045030 -0.016969  0.007635
# ...              ...       ...       ...       ...       ...       ...
# 2021-02-28 -0.026867  0.101382  0.007878  0.022379 -0.002447 -0.023633
# 2021-03-31 -0.027694 -0.007173 -0.007258  0.025132  0.012156 -0.023857
# 2021-04-30  0.017240  0.078266  0.011998  0.029524  0.006376  0.010012
# 2021-05-31  0.009831  0.038526  0.016488  0.034823  0.000390  0.004249
# 2021-06-30 -0.014598  0.024737  0.011335 -0.002378  0.012327  0.008170
#
#                  IYR       PSP       QAI       SHV       SPY       TIP
# Date
# 2009-04-30  0.296151  0.230202  0.022882  0.000554  0.099346 -0.017951
# 2009-05-31  0.022727  0.053892  0.027865 -0.000472  0.058454  0.019966
# 2009-06-30 -0.024863  0.045449 -0.003437  0.000599 -0.000655  0.001982
# 2009-07-31  0.105799  0.143247  0.015326 -0.000027  0.074605  0.000878
# 2009-08-31  0.131939  0.033413 -0.004151  0.000435  0.036940  0.008414
# ...              ...       ...       ...       ...       ...       ...
# 2021-02-28  0.024273  0.045824  0.001877  0.000000  0.027805 -0.016876
# 2021-03-31  0.057741  0.031651 -0.007181 -0.000090  0.045399 -0.002623
# 2021-04-30  0.078856  0.076499  0.005975  0.000000  0.052910  0.014297
# 2021-05-31  0.010082  0.018566  0.005939  0.000000  0.006566  0.010239
# 2021-06-30  0.032816 -0.000468  0.004661 -0.000181  0.022355  0.005398
#
# [147 rows x 12 columns]

# %%
retsx
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008439 -0.001554  0.155029  0.114637  0.137907 -0.028005
# 2009-05-31  0.054144  0.163135  0.159872  0.132390  0.029026 -0.020301
# 2009-06-30  0.004549 -0.026858 -0.023094 -0.014648  0.032918 -0.006171
# 2009-07-31  0.031312  0.018595  0.110173  0.100442  0.069217  0.008343
# 2009-08-31  0.007193 -0.040800 -0.013571  0.044595 -0.017404  0.007200
# ...              ...       ...       ...       ...       ...       ...
# 2021-02-28 -0.026867  0.101382  0.007878  0.022379 -0.002447 -0.023633
# 2021-03-31 -0.027604 -0.007082 -0.007168  0.025222  0.012246 -0.023766
# 2021-04-30  0.017240  0.078266  0.011998  0.029524  0.006376  0.010012
# 2021-05-31  0.009831  0.038526  0.016488  0.034823  0.000390  0.004249
# 2021-06-30 -0.014417  0.024918  0.011516 -0.002197  0.012508  0.008351
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# 2009-04-30  0.295597  0.229649  0.022329  0.098792 -0.018504
# 2009-05-31  0.023199  0.054364  0.028337  0.058926  0.020438
# 2009-06-30 -0.025463  0.044849 -0.004036 -0.001254  0.001382
# 2009-07-31  0.105826  0.143274  0.015353  0.074632  0.000905
# 2009-08-31  0.131504  0.032977 -0.004587  0.036504  0.007979
# ...              ...       ...       ...       ...       ...
# 2021-02-28  0.024273  0.045824  0.001877  0.027805 -0.016876
# 2021-03-31  0.057831  0.031742 -0.007090  0.045490 -0.002532
# 2021-04-30  0.078856  0.076499  0.005975  0.052910  0.014297
# 2021-05-31  0.010082  0.018566  0.005939  0.006566  0.010239
# 2021-06-30  0.032997 -0.000287  0.004842  0.022536  0.005579
#
# [147 rows x 11 columns]

# %%
with pd.ExcelWriter('multi_asset_return_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    rets.to_excel(writer, sheet_name='total returns')
    retsx.to_excel(writer, sheet_name='excess returns')
