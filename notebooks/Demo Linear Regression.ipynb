# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

path_to_data_file = 'multi_asset_returns.xlsx'

# %% [markdown]
# # Load the data from HW #1

# %%
retsx = pd.read_excel(path_to_data_file)
retsx.set_index('Date',inplace=True)
retsx
# Out:
#                  SPY       EFA       EEM       PSP       QAI       HYG  \
# Date
# 2009-04-30  0.098792  0.114636  0.155028  0.229649  0.022328  0.137877
# 2009-05-31  0.058925  0.132389  0.159871  0.054364  0.028336  0.028966
# 2009-06-30 -0.001274 -0.014910 -0.023135  0.044844 -0.004035  0.032761
# 2009-07-31  0.074632  0.100441  0.110172  0.143273  0.015352  0.069189
# 2009-08-31  0.036502  0.044593 -0.013573  0.032975 -0.004589 -0.017428
# ...              ...       ...       ...       ...       ...       ...
# 2021-02-28  0.027806  0.022379  0.007878  0.045824  0.001877 -0.002455
# 2021-03-31  0.045496  0.025222 -0.007168  0.031376 -0.007090  0.012204
# 2021-04-30  0.052910  0.029524  0.011999  0.076870  0.005975  0.006364
# 2021-05-31  0.006566  0.034823  0.016488  0.018566  0.005939  0.000388
# 2021-06-30  0.005456 -0.002236 -0.002983 -0.039417  0.000181  0.008353
#
#                  DBC       IYR       IEF       BWX       TIP
# Date
# ...

# %% [markdown]
# # Try a univariate regression, (just one X variable)

# %%
X = sm.add_constant(retsx['SPY'])
y = retsx['DBC']
model_uni = sm.OLS(y, X).fit()
model_uni.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    DBC   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     71.61
# Date:                Tue, 29 Jun 2021   Prob (F-statistic):           2.62e-14
# Time:                        11:16:34   Log-Likelihood:                 257.56
# No. Observations:                 147   AIC:                            -511.1
# Df Residuals:                     145   BIC:                            -505.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0091      0.004     -2.485      0.014      -0.016      -0.002
# ...

# %% [markdown]
# # Try a multivariate regression
#
# Does the beta on SPY change when we add a second regressor, compared to the single variable SPY?

# %%
X = sm.add_constant(retsx[['SPY','EFA']])
y = retsx['DBC']
model_multi = sm.OLS(y, X).fit()
model_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    DBC   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     49.64
# Date:                Tue, 29 Jun 2021   Prob (F-statistic):           4.00e-17
# Time:                        11:17:10   Log-Likelihood:                 266.61
# No. Observations:                 147   AIC:                            -527.2
# Df Residuals:                     144   BIC:                            -518.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0058      0.004     -1.619      0.108      -0.013       0.001
# ...
